# %%
# !pip install pymysql sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
# df1 = pd.read_csv("data/pizzas.csv") #Uncomment this and run
# df1 = pd.read_csv("pizzas.csv")
df1.isna().sum()
# Out:
# pizza_id         0
# pizza_type_id    0
# size             0
# price            0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
# df2 = pd.read_csv("data/pizzas_types.csv") #Uncomment this and run
# df2 = pd.read_csv("pizza_types.csv", encoding='latin1')
df2.isna().sum()
# Out:
# pizza_type_id    0
# name             0
# category         0
# ingredients      0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
# df3 = pd.read_csv("data/orders.csv") #Uncomment this and run
# df3 = pd.read_csv("orders.csv")
df3.isna().sum()
# Out:
# order_id    0
# date        0
# time        0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
# df3 = pd.read_csv("data/order_details.csv") #Uncomment this and run
# df4 = pd.read_csv("order_details.csv") 
df4.isna().sum()
# Out:
# order_details_id    0
# order_id            0
# pizza_id            0
# quantity            0
# dtype: int64

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
# mysql connection
# Corrected connection string (with '@' as '%40')
engine_mysql = create_engine("mysql+pymysql://root:password@localhost:3306/pizza_db") # open mysql and run this: create database pizza_db; use pizza_db;

try:
    engine_mysql
    print("Successful connection")
except:
    print("Unable to connect")
# Out:
# Successful connection

# %%
df1.to_sql(name='pizzas',con=engine_mysql,if_exists= 'append',index=False)
# Out:
# 96

# %%
df2.to_sql(name='pizza_details',con=engine_mysql,if_exists= 'append',index=False)
# Out:
# 32

# %%
df3.to_sql(name='orders',con=engine_mysql,if_exists= 'append',index=False)
# Out:
# 21350

# %%
df4.to_sql(name='order_details',con=engine_mysql,if_exists= 'append',index=False)
# Out:
# 48620
